# %% [markdown]
# <h1 style="color: #FF8C00;">Portfolio Analysis: Python Challenge</h1>
#
# ---
#
# **This challenge** represents a practical tech assignment designed to test your skills in portfolio analysis. Portfolio analysis is a systematic way to evaluate investment portfolios to optimize asset allocation and management. It involves a variety of financial metrics and visualizations to assess the performance and risk of different financial assets.
#
# - In this exercise, you will be required to perform a series of calculations and create visualizations to analyze a set of financial assets.
# - Your task is to develop the necessary code to accomplish each of these tasks effectively.
# - This challenge is an opportunity to demonstrate your ability to apply Python programming skills in a real-world financial context.

# %% [markdown]
# <h1 style="color: #FF8C00;">Libraries</h1>

# %% [markdown]
# <h3 style="color: #FF6347;">-- Insert your code here --</h3>
#
# ---
#
# Make sure to import all the libraries you will need to complete your tasks in this challenge.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sts

# %% [markdown]
# <h1 style="color: #FF8C00;">Exercise 1: Data Loading and Price Charting</h1>
#
# ---
#
# You are tasked with loading and analyzing financial data, which is foundational for effective portfolio management. Begin by loading the file named `asset_price_data.csv`, containing essential pricing information for various financial assets.
#
# Post data loading, your objective is to visualize this data through a time series graph.The integrity of your analysis depends heavily on your ability to visualize trends accurately while ensuring all asset price series begin at a uniform value.

# %% [markdown]
# <h3 style="color: #FF6347;">Data Loading</h3>
# <h3 style="color: #FF6347;">-- Insert your code here --</h3>

# %%
data = pd.read_csv('C:/Data_Science/IH_Notebooks/Week4_Tech_Challenge/asset_price_data.csv')

asset_df = data.copy()
asset_df
# Out:
#            date    Asset1   Asset2     Asset3  Asset4  Asset5
# 0    2019-01-02  231.5061   55.875  25.649222  302.93   50.89
# 1    2019-01-03  231.0356   54.977  25.503047  302.11   50.41
# 2    2019-01-04  230.4026   56.129  26.147133  301.77   51.38
# 3    2019-01-07  230.0543   56.838  25.955277  302.33   52.14
# 4    2019-01-08  229.7012   56.895  26.137997  303.42   52.13
# ..          ...       ...      ...        ...     ...     ...
# 778  2021-12-27  249.9207  103.956  38.820000     NaN   70.11
# 779  2021-12-28  249.9368  104.526  39.115000     NaN   70.03
# 780  2021-12-29  248.7215  104.360  38.855000  342.46   69.81
# 781  2021-12-30  248.5485  104.663  38.985000  342.55   69.91
# 782  2021-12-31  248.7545  104.106  39.005000  342.59     NaN
#
# [783 rows x 6 columns]

# %%
asset_df = asset_df.dropna()

# %%
asset_df['date'] = pd.to_datetime(asset_df['date'])
# Out:
# C:\Users\Mirko\AppData\Local\Temp\ipykernel_16436\1074916554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asset_df['date'] = pd.to_datetime(asset_df['date'])

# %%
num = asset_df.select_dtypes(include= 'number')
num
# Out:
#        Asset1   Asset2     Asset3  Asset4  Asset5
# 0    231.5061   55.875  25.649222  302.93   50.89
# 1    231.0356   54.977  25.503047  302.11   50.41
# 2    230.4026   56.129  26.147133  301.77   51.38
# 3    230.0543   56.838  25.955277  302.33   52.14
# 4    229.7012   56.895  26.137997  303.42   52.13
# ..        ...      ...        ...     ...     ...
# 774  251.4008  100.365  37.960000  342.13   67.93
# 775  251.1130  102.122  38.250000  342.21   68.81
# 776  250.1184  103.125  38.620000  342.38   69.18
# 780  248.7215  104.360  38.855000  342.46   69.81
# 781  248.5485  104.663  38.985000  342.55   69.91
#
# [730 rows x 5 columns]

# %% [markdown]
# <h1 style="color: #FF8C00;">Exercise 2: Daily Percentage Returns</h1>
#
# ---
#
# You are required to calculate the daily percentage returns for each financial asset. Utilize this data to accomplish the following:
# - Calculate the correlation matrix for the five assets.
# - Create a scatter plot comparing the returns of two specific assets.

# %% [markdown]
# <h2 style="color: #FF6347;">Daily Returns Calculation.</h2>
# <h3 style="color: #FF6347;">-- Insert your code here --</h3>

# %%
#pct_change() method to calculate the percentage change on each day
##the method can only be applied to numerical values hence why we created the num df beforehand.
daily_returns_df = num.pct_change()
daily_returns_df
# Out:
#        Asset1    Asset2    Asset3    Asset4    Asset5
# 0         NaN       NaN       NaN       NaN       NaN
# 1   -0.002032 -0.016072 -0.005699 -0.002707 -0.009432
# 2   -0.002740  0.020954  0.025255 -0.001125  0.019242
# 3   -0.001512  0.012632 -0.007338  0.001856  0.014792
# 4   -0.001535  0.001003  0.007040  0.003605 -0.000192
# ..        ...       ...       ...       ...       ...
# 774 -0.006078  0.014710  0.014973  0.000029  0.019970
# 775 -0.001145  0.017506  0.007640  0.000234  0.012955
# 776 -0.003961  0.009822  0.009673  0.000497  0.005377
# 780 -0.005585  0.011976  0.006085  0.000234  0.009107
# 781 -0.000696  0.002903  0.003346  0.000263  0.001432
#
# [730 rows x 5 columns]

# %%
daily_returns_df = daily_returns_df.dropna()

# %%
daily_returns_df.isnull().sum()
# Out:
# Asset1    0
# Asset2    0
# Asset3    0
# Asset4    0
# Asset5    0
# dtype: int64

# %% [markdown]
# <h2 style="color: #FF6347;">Correlation Matrix Calculation.</h2>
# <h3 style="color: #FF6347;">-- Insert your code here --</h3>

# %%
#correlation matrix
correlation_matrix = num.corr()
correlation_matrix
# Out:
#           Asset1    Asset2    Asset3    Asset4    Asset5
# Asset1  1.000000  0.512296  0.380556  0.568261  0.069369
# Asset2  0.512296  1.000000  0.906736  0.880134  0.827004
# Asset3  0.380556  0.906736  1.000000  0.880221  0.865331
# Asset4  0.568261  0.880134  0.880221  1.000000  0.779235
# Asset5  0.069369  0.827004  0.865331  0.779235  1.000000

# %%
sns.heatmap(data=correlation_matrix,  annot=True, cmap="coolwarm", fmt=".2f")

plt.show()

# %% [markdown]
# The correlation matrix above shows how different assets are related. The value can move from -1 to 1 where the closer we are to 1 the stronger is the positive relation and -1 the stronger is the negative relation. If we are close to 0 the relation between the assets is weak.
#
# To notice how Asset 2 and 3 seem to have a strong correlation, meaning that with one increasing the other will increase as well.

# %% [markdown]
# <h2 style="color: #FF6347;">Scatter Plot between the Returns of Two Assets.</h2>
# <h3 style="color: #FF6347;">-- Insert your code here --</h3>

# %%
#scatter plot to show relationship between asset 2 and 3
sns.scatterplot(x=num["Asset2"], y=num["Asset3"])
# Out:
# <Axes: xlabel='Asset2', ylabel='Asset3'>

# %%
from scipy.stats import spearmanr

corr, _ = spearmanr(num["Asset2"], num["Asset3"])
print(f"Spearman's Rank Correlation: {corr:.2f}")
# Out:
# Spearman's Rank Correlation: 0.85

# %%
sns.scatterplot(x=num["Asset2"], y=num["Asset4"])
# Out:
# <Axes: xlabel='Asset2', ylabel='Asset4'>

# %%
corr, _ = spearmanr(num["Asset2"], num["Asset4"])
print(f"Spearman's Rank Correlation: {corr:.2f}")
# Out:
# Spearman's Rank Correlation: 0.92

# %%
sns.scatterplot(x=num["Asset2"], y=num["Asset5"])
# Out:
# <Axes: xlabel='Asset2', ylabel='Asset5'>

# %%
corr, _ = spearmanr(num["Asset2"], num["Asset5"])
print(f"Spearman's Rank Correlation: {corr:.2f}")
# Out:
# Spearman's Rank Correlation: 0.63

# %% [markdown]
# The above scatter plots show a monotoic relationship between the assets 2, 3, 4 and 5.
#
# The asset values will increase if the other correlated value increases. The increase might not always be linear as we can see between Asset 2 and Asset 4 but the trend will always be monotonic.
#
# This information can be used to further develop the portfolio strategy.

# %% [markdown]
# <h1 style="color: #FF8C00;">Exercise 3: Portfolio Analysis</h1>
#
# ---
#
# This third exercise focuses on calculating and analyzing the performance of a portfolio. Begin by loading the file named `portfolio_weights.csv`, which contains the daily weights of each asset in the portfolio.
#
# To complete the exercise, you will need to perform the following tasks:
# - Create an area chart of the asset weights.
# - Plot the historical cumulative returns of the portfolio.
# - Calculate the annualized return of the portfolio.
# - Determine the annualized volatility of the portfolio (using an annualization factor of 261 days).
# - Produce an area chart grouping asset weights by their categories, as detailed in the `asset_information_data.csv`.

# %%
#pulling the data from csv file
portfolio_df =  pd.read_csv('C:/Data_Science/IH_Notebooks/Week4_Tech_Challenge/portfolio_weights.csv')

portfolio_df.head()
# Out:
#          date    Asset1    Asset2    Asset3   Asset4    Asset5
# 0  2019-01-02  0.225458  0.116255  0.265003  0.23031  0.162974
# 1  2019-01-03  0.225458  0.116255  0.265003  0.23031  0.162974
# 2  2019-01-04  0.225458  0.116255  0.265003  0.23031  0.162974
# 3  2019-01-07  0.225458  0.116255  0.265003  0.23031  0.162974
# 4  2019-01-08  0.225458  0.116255  0.265003  0.23031  0.162974

# %%
portfolio_df['date'] = pd.to_datetime(portfolio_df['date'])

# %%
num_portfolio = portfolio_df.select_dtypes(include='number')

# %% [markdown]
# <h2 style="color: #FF6347;">Area Chart of Asset Weights.</h2>
# <h3 style="color: #FF6347;">-- Insert your code here --</h3>

# %%
x = portfolio_df['date']
y1= num_portfolio['Asset1']
y2=num_portfolio['Asset2']
y3=num_portfolio['Asset3']
y4=num_portfolio['Asset4']
y5=num_portfolio['Asset5']

# Basic stacked area chart.
plt.figure(figsize=(20, 10))
plt.stackplot(x,y1, y2, y3, y4, y5, labels=['Asset1','Asset2','Asset3', 'Asset4', 'Asset5'])
plt.legend(loc='upper left')

# %% [markdown]
# <h2 style="color: #FF6347;">Chart of Historical Cumulative Returns of the Portfolio.</h2>
# <h3 style="color: #FF6347;">-- Insert your code here --</h3>

# %%
#using the align method to remove non matching rows
##I have removed the first row of daily returns as it was the very first day of the portfolio and had NaN values
daily_returns_df, num_portfolio = daily_returns_df.align(num_portfolio, join="inner")

# %%
daily_returns_df.shape
# Out:
# (729, 5)

# %%
num_portfolio.shape
# Out:
# (729, 5)

# %%
#calculating the daily return

weighted_returns = daily_returns_df * num_portfolio

weighted_returns
# Out:
#        Asset1    Asset2    Asset3    Asset4    Asset5
# 1   -0.000458 -0.001868 -0.001510 -0.000623 -0.001537
# 2   -0.000618  0.002436  0.006693 -0.000259  0.003136
# 3   -0.000341  0.001468 -0.001944  0.000427  0.002411
# 4   -0.000346  0.000117  0.001866  0.000830 -0.000031
# 5    0.000445  0.001502  0.000602  0.000949  0.002282
# ..        ...       ...       ...       ...       ...
# 774 -0.000433  0.003914  0.002527  0.000010  0.003162
# 775 -0.000082  0.004658  0.001289  0.000078  0.002051
# 776 -0.000282  0.002613  0.001633  0.000167  0.000851
# 780 -0.000398  0.003187  0.001027  0.000078  0.001442
# 781 -0.000050  0.000773  0.000565  0.000088  0.000227
#
# [729 rows x 5 columns]

# %%
portfolio_daily_returns = weighted_returns.sum(axis=1)
portfolio_daily_returns
# Out:
# 1     -0.005997
# 2      0.011388
# 3      0.002021
# 4      0.002435
# 5      0.005780
#          ...
# 774    0.009180
# 775    0.007996
# 776    0.004982
# 780    0.005336
# 781    0.001603
# Length: 729, dtype: float64

# %%
portfolio_df['Daily Return'] = portfolio_daily_returns
portfolio_df
# Out:
#           date    Asset1    Asset2    Asset3   Asset4    Asset5  Daily Return
# 0   2019-01-02  0.225458  0.116255  0.265003  0.23031  0.162974           NaN
# 1   2019-01-03  0.225458  0.116255  0.265003  0.23031  0.162974     -0.005997
# 2   2019-01-04  0.225458  0.116255  0.265003  0.23031  0.162974      0.011388
# 3   2019-01-07  0.225458  0.116255  0.265003  0.23031  0.162974      0.002021
# 4   2019-01-08  0.225458  0.116255  0.265003  0.23031  0.162974      0.002435
# ..         ...       ...       ...       ...      ...       ...           ...
# 778 2021-12-27  0.071307  0.266093  0.168775  0.33547  0.158356           NaN
# 779 2021-12-28  0.071307  0.266093  0.168775  0.33547  0.158356           NaN
# 780 2021-12-29  0.071307  0.266093  0.168775  0.33547  0.158356      0.005336
# 781 2021-12-30  0.071307  0.266093  0.168775  0.33547  0.158356      0.001603
# 782 2021-12-31  0.071307  0.266093  0.168775  0.33547  0.158356           NaN
#
# [783 rows x 7 columns]

# %%
import warnings 
warnings.filterwarnings('ignore')
portfolio_df['Daily Return'].fillna(method='ffill', inplace= True)
portfolio_df
# Out:
#           date    Asset1    Asset2    Asset3   Asset4    Asset5  Daily Return
# 0   2019-01-02  0.225458  0.116255  0.265003  0.23031  0.162974           NaN
# 1   2019-01-03  0.225458  0.116255  0.265003  0.23031  0.162974     -0.005997
# 2   2019-01-04  0.225458  0.116255  0.265003  0.23031  0.162974      0.011388
# 3   2019-01-07  0.225458  0.116255  0.265003  0.23031  0.162974      0.002021
# 4   2019-01-08  0.225458  0.116255  0.265003  0.23031  0.162974      0.002435
# ..         ...       ...       ...       ...      ...       ...           ...
# 778 2021-12-27  0.071307  0.266093  0.168775  0.33547  0.158356      0.004982
# 779 2021-12-28  0.071307  0.266093  0.168775  0.33547  0.158356      0.004982
# 780 2021-12-29  0.071307  0.266093  0.168775  0.33547  0.158356      0.005336
# 781 2021-12-30  0.071307  0.266093  0.168775  0.33547  0.158356      0.001603
# 782 2021-12-31  0.071307  0.266093  0.168775  0.33547  0.158356      0.001603
#
# [783 rows x 7 columns]

# %%
plt.figure(figsize=(20, 10))

# Plot daily portfolio returns with better styling
plt.plot(portfolio_df['date'], portfolio_df['Daily Return'], color='blue', linewidth=1.5, label="Daily Return")

# Add title and labels
plt.title("Portfolio Daily Returns Over Time", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Daily Return (%)", fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add a grid for clarity
plt.grid(True, linestyle='--', alpha=0.7)

# Show legend
plt.legend()

# Show the chart
plt.show()

# %% [markdown]
# <h2 style="color: #FF6347;">Annualized Return.</h2>
# <h3 style="color: #FF6347;">-- Insert your code here --</h3>

# %%
cumulative_returns = (1 + portfolio_df['Daily Return']).prod() - 1
cumulative_returns
# Out:
# np.float64(0.47982463850363044)

# %% [markdown]
# <h2 style="color: #FF6347;">Annualized Volatility.</h2>
# <h3 style="color: #FF6347;">-- Insert your code here --</h3>

# %%
annualized_return = (1 + cumulative_returns) ** (261 / len(portfolio_df)) - 1
annualized_return
# Out:
# np.float64(0.13955883168068461)

# %% [markdown]
# <h2 style="color: #FF6347;">Area Chart of Asset Weights Grouped by Family.</h2>
# <h3 style="color: #FF6347;">-- Insert your code here --</h3>

# %%
asset_info = pd.read_csv('C:/Data_Science/IH_Notebooks/Week4_Tech_Challenge/asset_information_data.csv')
asset_info
# Out:
#      Name        Family
# 0  Asset1  Fixed Income
# 1  Asset2  Fixed Income
# 2  Asset3        Equity
# 3  Asset4        Equity
# 4  Asset5   Alternative

# %%
#creating a new df from the num_portfolio to change column names

asset_category_weight = portfolio_df.copy()
asset_category_weight
# Out:
#           date    Asset1    Asset2    Asset3   Asset4    Asset5  Daily Return
# 0   2019-01-02  0.225458  0.116255  0.265003  0.23031  0.162974           NaN
# 1   2019-01-03  0.225458  0.116255  0.265003  0.23031  0.162974     -0.005997
# 2   2019-01-04  0.225458  0.116255  0.265003  0.23031  0.162974      0.011388
# 3   2019-01-07  0.225458  0.116255  0.265003  0.23031  0.162974      0.002021
# 4   2019-01-08  0.225458  0.116255  0.265003  0.23031  0.162974      0.002435
# ..         ...       ...       ...       ...      ...       ...           ...
# 778 2021-12-27  0.071307  0.266093  0.168775  0.33547  0.158356      0.004982
# 779 2021-12-28  0.071307  0.266093  0.168775  0.33547  0.158356      0.004982
# 780 2021-12-29  0.071307  0.266093  0.168775  0.33547  0.158356      0.005336
# 781 2021-12-30  0.071307  0.266093  0.168775  0.33547  0.158356      0.001603
# 782 2021-12-31  0.071307  0.266093  0.168775  0.33547  0.158356      0.001603
#
# [783 rows x 7 columns]

# %%
asset_category_weight = asset_category_weight.rename(columns={'Asset1' : 'Fixed Income 1', 'Asset2' : 'Fixed Income 2', 'Asset3': 'Equity 1', 'Asset4' : 'Equity 2', 'Asset5' : 'Alternative'})
asset_category_weight
# Out:
#           date  Fixed Income 1  Fixed Income 2  Equity 1  Equity 2  \
# 0   2019-01-02        0.225458        0.116255  0.265003   0.23031
# 1   2019-01-03        0.225458        0.116255  0.265003   0.23031
# 2   2019-01-04        0.225458        0.116255  0.265003   0.23031
# 3   2019-01-07        0.225458        0.116255  0.265003   0.23031
# 4   2019-01-08        0.225458        0.116255  0.265003   0.23031
# ..         ...             ...             ...       ...       ...
# 778 2021-12-27        0.071307        0.266093  0.168775   0.33547
# 779 2021-12-28        0.071307        0.266093  0.168775   0.33547
# 780 2021-12-29        0.071307        0.266093  0.168775   0.33547
# 781 2021-12-30        0.071307        0.266093  0.168775   0.33547
# 782 2021-12-31        0.071307        0.266093  0.168775   0.33547
#
#      Alternative  Daily Return
# 0       0.162974           NaN
# 1       0.162974     -0.005997
# 2       0.162974      0.011388
# 3       0.162974      0.002021
# ...

# %%
if "date" in asset_category_weight.columns:
    asset_category_weight["date"] = pd.to_datetime(asset_category_weight["date"])
    asset_category_weight.set_index("date", inplace=True)

fig, ax1 = plt.subplots(figsize=(12, 6))

asset_category_weight.drop(columns=["Daily Return"]).plot(kind='area', stacked=True, alpha=0.75, colormap='tab10', ax=ax1)

ax1.set_title("Portfolio Asset Weights by Category Over Time with Daily Return")
ax1.set_xlabel("Date")
ax1.set_ylabel("Portfolio Weight")
ax1.legend(title="Category", bbox_to_anchor=(1.05, 1), loc='upper left')
ax1.grid(axis='y', linestyle='--', alpha=0.6)

ax2 = ax1.twinx()
asset_category_weight["Daily Return"].plot(kind='line', color='blue', linewidth=2, ax=ax2, label="Daily Return")
ax2.set_ylabel("Daily Return", color='black')
ax2.legend(loc='upper right')

plt.show()

# %% [markdown]
# **Conclusions:**
#
# The portfolio has grown 48% from the start date and at a pace of 14% each year.
#
# The Daily Return plot shows a low level of volability with drops explained by world wide crisis such as the one of the pandemic in 2020.
